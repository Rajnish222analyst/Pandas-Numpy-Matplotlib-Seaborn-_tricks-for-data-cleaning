# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
data=pd.read_csv("F:\height.csv")

# %%
data.head()
# Out:
#   Name  Height
# 0    A     5.9
# 1    B     5.2
# 2    C     5.1
# 3    D     5.5
# 4    E     4.9

# %%
max_threshold=data['Height'].quantile(.95)
max_threshold
# Out:
# 8.66

# %%
data[data['Height'] > max_threshold]
# Out:
#    Name  Height
# 11    L     9.5

# %%
min_threshold=data['Height'].quantile(.05)
min_threshold
# Out:
# 5.04

# %%
data[data['Height']<min_threshold]
# Out:
#   Name  Height
# 4    E     4.9

# %%
# Remove outliers
data[(data['Height']<max_threshold) & (data['Height']>min_threshold)]
# Out:
#    Name  Height
# 0     A     5.9
# 1     B     5.2
# 2     C     5.1
# 3     D     5.5
# 5     F     6.4
# 6     G     5.4
# 7     H     6.2
# 8     I     6.5
# 9     J     6.1
# 10    K     7.1
# 12    M     7.8
# 13    N     8.0
# 14    O     8.3

# %%
# Banglore house price
df=pd.read_csv("F:\Bengaluru_House_Data.csv")

# %%
df.shape
# Out:
# (13320, 9)

# %%
df.describe()
# Out:
#                bath       balcony         price
# count  13247.000000  12711.000000  13320.000000
# mean       2.692610      1.584376    112.565627
# std        1.341458      0.817263    148.971674
# min        1.000000      0.000000      8.000000
# 25%        2.000000      1.000000     50.000000
# 50%        2.000000      2.000000     72.000000
# 75%        3.000000      2.000000    120.000000
# max       40.000000      3.000000   3600.000000

# %%
min_threshold, max_threshold=df['price'].quantile([.01, .99])
min_threshold, max_threshold
# Out:
# (18.5, 658.0999999999949)

# %%
df[df['price'] >  max_threshold]
# Out:
#                   area_type   availability  \
# 159              Plot  Area  Ready To Move
# 408    Super built-up  Area         19-Jan
# 440              Plot  Area  Ready To Move
# 605    Super built-up  Area         19-Jan
# 641              Plot  Area  Ready To Move
# ...                     ...            ...
# 13086  Super built-up  Area  Ready To Move
# 13095  Super built-up  Area  Ready To Move
# 13119            Plot  Area  Ready To Move
# 13197            Plot  Area  Ready To Move
# 13200            Plot  Area  Ready To Move
#
#                                              location       size  society  \
# 159                                Mahalakshmi Layout  4 Bedroom      NaN
# 408                                      Rajaji Nagar      7 BHK      NaN
# 440                                        Whitefield  4 Bedroom      NaN
# 605                                      Malleshwaram      7 BHK      NaN
# ...

# %%
df[df['price'] >  min_threshold]
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13314  Super built-up  Area  Ready To Move         Green Glen Layout
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
# Remove outliers
df1=[(df['price'] >  max_threshold)&(df['price'] >  min_threshold)]
df1
# Out:
# [0        False
#  1        False
#  2        False
#  3        False
#  4        False
#           ...
#  13315    False
#  13316    False
#  13317    False
#  13318    False
#  13319    False
#  Name: price, Length: 13320, dtype: bool]

# %%
# How to remove outliers from Airbnb data
df_ab=pd.read_csv("F:\AB_NYC_2019.csv")
df_ab.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
df_ab.price.describe()
# Out:
# count    48895.000000
# mean       152.720687
# std        240.154170
# min          0.000000
# 25%         69.000000
# 50%        106.000000
# 75%        175.000000
# max      10000.000000
# Name: price, dtype: float64

# %%
# taking 
min_thresold, max_thresold = df_ab.price.quantile([.01, .99])
min_thresold, max_thresold
# Out:
# (30.0, 799.0)

# %%
df_ab2 = df_ab[(df_ab['price']<max_thresold)&(df_ab['price']>min_thresold)]
df_ab2.price.describe()
# Out:
# count    47744.000000
# mean       138.832503
# std        102.890554
# min         31.000000
# 25%         70.000000
# 50%        108.000000
# 75%        175.000000
# max        795.000000
# Name: price, dtype: float64

# %%
min_thresold, max_thresold=df_ab.price.quantile([.05, .95])
min_thresold, max_thresold
# Out:
# (40.0, 355.0)

# %%
df_ab3=df_ab[(df_ab.price<max_thresold)&(df_ab.price>min_thresold)]
df_ab3.price.describe()
# Out:
# count    43631.000000
# mean       128.201187
# std         70.515988
# min         41.000000
# 25%         72.000000
# 50%        109.000000
# 75%        169.000000
# max        353.000000
# Name: price, dtype: float64
